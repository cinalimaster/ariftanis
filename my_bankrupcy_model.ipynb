# %% [markdown]
# <a href="https://colab.research.google.com/github/cinalimaster/ariftanis/blob/main/my_bankrupcy_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
data = pd.read_csv("bank.csv")
data.head()
# Out:
#    Bankrupt?  ...   Equity to Liability
# 0          1  ...              0.016469
# 1          1  ...              0.020794
# 2          1  ...              0.016474
# 3          1  ...              0.023982
# 4          1  ...              0.035490
#
# [5 rows x 96 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.heatmap(data.corr())
plt.show()

# %%
X = data.drop(["Bankrupt?"], axis="columns")
y = data["Bankrupt?"]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
logreg = LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
                   intercept_scaling=1, l1_ratio=None, max_iter=400,
                   multi_class='auto', n_jobs=None, penalty='l2',
                   random_state=None, solver='lbfgs', tol=0.1, verbose=0,
                   warm_start=False)
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=400,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.1, verbose=0,
#                    warm_start=False)

# %%
logreg.score(x_test, y_test)
# Out:
# 0.9567448680351907
